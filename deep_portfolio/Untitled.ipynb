# %%
import pandas as pd

# %%
df = pd.read_csv('./data/CNA_portfolio.csv')

# %%
df.head()
# Out:
#          Date  000002 SZ T1440  000089 SZ T1440  000157 SZ T1440  \
# 0  2012-01-05         5.608798         3.807883         5.697452
# 1  2012-01-06         5.480905         3.801978         5.567221
# 2  2012-01-07         5.527596         3.890607         5.758363
# 3  2012-01-08         5.527596         3.890607         5.758363
# 4  2012-01-09         5.527596         3.890607         5.758363
#
#    000568 SZ T1440  000581 SZ T1440  000651 SZ T1440  000858 SZ T1440  \
# 0        26.510463        17.259812         6.377904        25.794077
# 1        26.828842        16.993895         6.197429        25.972654
# 2        26.616697        16.451072         6.366991        25.898051
# 3        26.616697        16.451072         6.366991        25.898051
# 4        26.616697        16.451072         6.366991        25.898051
#
#    000951 SZ T1440  000997 SZ T1440       ...         002311 SZ T1440  \
# 0         6.423874         5.524119       ...                6.271071
# ...

# %%
df.shape
# Out:
# (2795, 66)
